# %% [markdown]
# <a href="https://colab.research.google.com/github/SETHU01TAMIL/valueadded-sethu/blob/main/normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as ps

# %%
import matplotlib.pyplot as malt

# %%
from sklearn.preprocessing import Normalizer

# %%
norm_df=ps.DataFrame({'x':np.random.randint(-100,100,1000),
                      'y':np.random.randint(-80,80,1000),
                      'z':np.random.randint(-150,150,1000)})

# %%
norm_df
# Out:
#       x   y    z
# 0   -31  41  -51
# 1    57 -40  -96
# 2    -9  25  -37
# 3    29  79  -28
# 4   -51  -6  141
# ..   ..  ..  ...
# 995  87  58  -90
# 996  99   0   98
# 997 -14  54   81
# 998   6 -57   97
# 999  75 -73  -84
#
# [1000 rows x 3 columns]

# %%
ax=malt.axes(projection='3d')
ax.scatter3D(norm_df.x,norm_df.y,norm_df.z)
malt.figure()

# %%
normal=Normalizer()

# %%
norm_df=normal.fit_transform(norm_df)
norm_df
# Out:
# array([[-0.42812616,  0.56623137, -0.70433658],
#        [ 0.48062348, -0.33727964, -0.80947113],
#        [-0.19757567,  0.5488213 , -0.81225552],
#        ...,
#        [-0.14234671,  0.54905161,  0.82357741],
#        [ 0.05325397, -0.50591273,  0.86093921],
#        [ 0.55886178, -0.5439588 , -0.62592519]])

# %%
norm_df=ps.DataFrame(norm_df,columns=['x','y','z'])
norm_df
# Out:
#             x         y         z
# 0   -0.428126  0.566231 -0.704337
# 1    0.480623 -0.337280 -0.809471
# 2   -0.197576  0.548821 -0.812256
# 3    0.326980  0.890738 -0.315705
# 4   -0.339864 -0.039984  0.939624
# ..        ...       ...       ...
# 995  0.630617  0.420411 -0.652362
# 996  0.710687  0.000000  0.703508
# 997 -0.142347  0.549052  0.823577
# 998  0.053254 -0.505913  0.860939
# 999  0.558862 -0.543959 -0.625925
#
# [1000 rows x 3 columns]

# %%
ax=malt.axes(projection='3d')
ax.scatter3D(norm_df.x,norm_df.y,norm_df.z)
malt.figure()

# %%
data={'first score':[100,90,np.nan,95],
      'second score':[30,45,56,np.nan],
      'third score':[np.nan,40,80,98]}

# %%
data
# Out:
# {'first score': [100, 90, nan, 95],
#  'second score': [30, 45, 56, nan],
#  'third score': [nan, 40, 80, 98]}

# %%
var=ps.DataFrame(data)

# %%
var
# Out:
#    first score  second score  third score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2          NaN          56.0         80.0
# 3         95.0           NaN         98.0

# %%
var.isnull()
var.isnull().sum()
# Out:
# first score     1
# second score    1
# third score     1
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
imputer=SimpleImputer(missing_values=np.nan,strategy='mean')

# %%
imputer
# Out:
# SimpleImputer()

# %%
imputer.fit(var)
imputer.transform(var)
# Out:
# array([[100.        ,  30.        ,  72.66666667],
#        [ 90.        ,  45.        ,  40.        ],
#        [ 95.        ,  56.        ,  80.        ],
#        [ 95.        ,  43.66666667,  98.        ]])
